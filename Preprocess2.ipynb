# %%
import numpy as np
from PIL import Image
from PIL import ImageOps
from matplotlib import pyplot as plt

# %%
im = Image.open("practice.jpg")

# %%
im.show()

# %%
width, height = im.size

# %%
print width
print height
# Out:
# 480
# 640

# %%
res_img = ImageOps.fit(im, (224,224), Image.ANTIALIAS)

# %%
res_img.show()

# %%
width1, height1 = res_img.size

# %%
plt.imshow(res_img)
plt.show()

# %%
print width1
print height1
# Out:
# 224
# 224

# %%
area = (60, 115, 420, 579)
cropped_img = im.crop(area)
cropped_img.show()

# %%
plt.imshow(cropped_img)
plt.show()

# %%
cropped_img.save("cropped2.jpg","JPEG")
