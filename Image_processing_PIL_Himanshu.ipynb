# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os as os
os.chdir('/home/himanshu')

# %%
## Downloading the image from given URL

import urllib
urllib.urlretrieve('https://assets.myntassets.com/h_640,q_90,w_480/v1/assets/images/2354027/2018/1/16/11516097831111-MsTaken-Women-Navy-Blue-Striped-Top-4731516097830960-1.jpg', './test2.jpg')

# %%
## Loading from the URL

from PIL import Image
import requests
from StringIO import StringIO

url = 'https://assets.myntassets.com/h_640,q_90,w_480/v1/assets/images/2354027/2018/1/16/11516097831111-MsTaken-Women-Navy-Blue-Striped-Top-4731516097830960-1.jpg'
response = requests.get(url)
img = Image.open(StringIO(response.content))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x640 at 0x7F299C4A5ED0>

# %%
## Reading the image
img1 = Image.open('test2.jpg')
img1.show()

# %%
## Size, mode and format of the Image
print('Size: (%d,%d)'%(img1.size))
print('Mode: %s' %(img1.mode))
print('Format: %s'%(img1.format))
# Out:
# Size: (480,640)
# Mode: RGB
# Format: JPEG

# %%
## Resizing the image to 224x224
img_r = img1.resize((224,224))
img_r.show()

# %%
## Cropping and saving the cropped image
box = 60, 115, 420, 579
crop_pil = img1.crop(box)
crop_pil.save('crop_pil.jpg')
