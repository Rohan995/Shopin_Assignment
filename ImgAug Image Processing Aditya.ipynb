# %%
import numpy as np
import matplotlib.pyplot as plt
from imgaug import augmenters as iaa
# %matplotlib inline

# %%
url='https://assets.myntassets.com/h_640,q_90,w_480/v1/assets/images/2354027/2018/1/16/11516097831111-MsTaken-Women-Navy-Blue-Striped-Top-4731516097830960-1.jpg'

# %%
import urllib.request

# %%
import cv2
resp = urllib.request.urlopen(url)
image = np.asarray(bytearray(resp.read()), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_COLOR)
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
image.shape
# Out:
# (640, 480, 3)

# %%
image=image.reshape(1,640,480,3)
aug = iaa.Scale({"height": 224, "width": 224})
image_resize = aug.augment_images(image) 
image_resize=image_resize.reshape(224,224,3)
image_resize.shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(image_resize)

# %%
aug1=iaa.Crop(px=( 115,  60,61, 60))

# %%
img_crop=aug1.augment_images(image)
img_crop.shape
# Out:
# (1, 640, 480, 3)

# %%
img_crop=img_crop.reshape(640,480,3)
plt.imshow(img_crop)

# %%
cv2.imwrite('imgaug.jpg',img_crop)
# Out:
# True
