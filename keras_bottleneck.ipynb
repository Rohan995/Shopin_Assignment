# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense
from keras import applications

# dimensions of our images.
img_width, img_height = 150, 150

top_model_weights_path = 'bottleneck_fc_model.h5'
train_data_dir = 'data/train'
validation_data_dir = 'data/validation'
nb_train_samples = 2000
nb_validation_samples = 800
epochs = 50
batch_size = 16


def save_bottlebeck_features():
    datagen = ImageDataGenerator(rescale=1. / 255)

    # build the VGG16 network
    model = applications.VGG16(include_top=False, weights='imagenet')

    generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    bottleneck_features_train = model.predict_generator(
        generator, nb_train_samples // batch_size)
    np.save(open('bottleneck_features_train.npy', 'w'),
            bottleneck_features_train)

    generator = datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    bottleneck_features_validation = model.predict_generator(
        generator, nb_validation_samples // batch_size)
    np.save(open('bottleneck_features_validation.npy', 'w'),
            bottleneck_features_validation)


def train_top_model():
    train_data = np.load(open('bottleneck_features_train.npy'))
    train_labels = np.array(
        [0] * (nb_train_samples / 2) + [1] * (nb_train_samples / 2))

    validation_data = np.load(open('bottleneck_features_validation.npy'))
    validation_labels = np.array(
        [0] * (nb_validation_samples / 2) + [1] * (nb_validation_samples / 2))

    model = Sequential()
    model.add(Flatten(input_shape=train_data.shape[1:]))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy', metrics=['accuracy'])

    model.fit(train_data, train_labels,
              epochs=epochs,
              batch_size=batch_size,
              validation_data=(validation_data, validation_labels))
    model.save_weights(top_model_weights_path)


save_bottlebeck_features()
train_top_model()
# Out:
# Using TensorFlow backend.
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Train on 2000 samples, validate on 800 samples
# Epoch 1/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.7311 - acc: 0.7550 - val_loss: 0.6776 - val_acc: 0.7150
# Epoch 2/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.4218 - acc: 0.8200 - val_loss: 0.2818 - val_acc: 0.8712
# Epoch 3/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.3212 - acc: 0.8750 - val_loss: 0.5680 - val_acc: 0.7837
# Epoch 4/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.3134 - acc: 0.8760 - val_loss: 0.3246 - val_acc: 0.8650
# Epoch 5/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.2504 - acc: 0.8975 - val_loss: 0.2849 - val_acc: 0.8938
# Epoch 6/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.2480 - acc: 0.9135 - val_loss: 0.2776 - val_acc: 0.8912
# Epoch 7/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.2064 - acc: 0.9195 - val_loss: 0.2633 - val_acc: 0.8950
# Epoch 8/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.1848 - acc: 0.9300 - val_loss: 0.3081 - val_acc: 0.8900
# Epoch 9/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.1751 - acc: 0.9365 - val_loss: 0.3176 - val_acc: 0.8988
# Epoch 10/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.1482 - acc: 0.9510 - val_loss: 0.3320 - val_acc: 0.9000
# Epoch 11/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.1535 - acc: 0.9435 - val_loss: 0.3379 - val_acc: 0.8875
# Epoch 12/50
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1376 - acc: 0.9520 - val_loss: 0.3684 - val_acc: 0.8900
# Epoch 13/50
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1066 - acc: 0.9600 - val_loss: 0.3401 - val_acc: 0.8862
# Epoch 14/50
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.0964 - acc: 0.9655 - val_loss: 0.3663 - val_acc: 0.8950
# Epoch 15/50
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.0919 - acc: 0.9635 - val_loss: 0.3801 - val_acc: 0.8988
# Epoch 16/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.0707 - acc: 0.9720 - val_loss: 0.4195 - val_acc: 0.8875
# Epoch 17/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.0668 - acc: 0.9740 - val_loss: 0.4569 - val_acc: 0.8938
# Epoch 18/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.0660 - acc: 0.9790 - val_loss: 0.4072 - val_acc: 0.9012
# Epoch 19/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.0718 - acc: 0.9725 - val_loss: 0.7247 - val_acc: 0.8538
# Epoch 20/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.0645 - acc: 0.9770 - val_loss: 0.8879 - val_acc: 0.8387
# Epoch 21/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.0493 - acc: 0.9850 - val_loss: 0.5357 - val_acc: 0.8925
# Epoch 22/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.0494 - acc: 0.9850 - val_loss: 0.5151 - val_acc: 0.8962
# Epoch 23/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.0367 - acc: 0.9870 - val_loss: 0.5713 - val_acc: 0.8875
# Epoch 24/50
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.0373 - acc: 0.9855 - val_loss: 0.6230 - val_acc: 0.8925
# Epoch 25/50
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.0394 - acc: 0.9860 - val_loss: 1.0044 - val_acc: 0.8450
# Epoch 26/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.0366 - acc: 0.9895 - val_loss: 0.5634 - val_acc: 0.8912
# Epoch 27/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0242 - acc: 0.9910 - val_loss: 0.7302 - val_acc: 0.8888
# Epoch 28/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0372 - acc: 0.9905 - val_loss: 0.5727 - val_acc: 0.8925
# Epoch 29/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0290 - acc: 0.9900 - val_loss: 0.6879 - val_acc: 0.8938
# Epoch 30/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0259 - acc: 0.9925 - val_loss: 0.7728 - val_acc: 0.8862
# Epoch 31/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0362 - acc: 0.9905 - val_loss: 0.6204 - val_acc: 0.8912
# Epoch 32/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0383 - acc: 0.9880 - val_loss: 0.6113 - val_acc: 0.8988
# Epoch 33/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0274 - acc: 0.9900 - val_loss: 0.7796 - val_acc: 0.8800
# Epoch 34/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.0132 - acc: 0.9950 - val_loss: 0.6465 - val_acc: 0.8900
# Epoch 35/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0213 - acc: 0.9935 - val_loss: 0.6284 - val_acc: 0.9000
# Epoch 36/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0246 - acc: 0.9930 - val_loss: 0.9516 - val_acc: 0.8600
# Epoch 37/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0167 - acc: 0.9930 - val_loss: 0.7345 - val_acc: 0.8925
# Epoch 38/50
# 2000/2000 [==============================] - 4s 2ms/step - loss: 0.0148 - acc: 0.9945 - val_loss: 0.7350 - val_acc: 0.8925
# Epoch 39/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0239 - acc: 0.9940 - val_loss: 0.7303 - val_acc: 0.8975
# Epoch 40/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0146 - acc: 0.9950 - val_loss: 0.8157 - val_acc: 0.8875
# Epoch 41/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0304 - acc: 0.9915 - val_loss: 0.7700 - val_acc: 0.8925
# Epoch 42/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0158 - acc: 0.9940 - val_loss: 0.7118 - val_acc: 0.9000
# Epoch 43/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0104 - acc: 0.9965 - val_loss: 0.7575 - val_acc: 0.8962
# Epoch 44/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0300 - acc: 0.9930 - val_loss: 0.7073 - val_acc: 0.8950
# Epoch 45/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0092 - acc: 0.9970 - val_loss: 1.1610 - val_acc: 0.8600
# Epoch 46/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0136 - acc: 0.9960 - val_loss: 0.7342 - val_acc: 0.8962
# Epoch 47/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0154 - acc: 0.9965 - val_loss: 0.8613 - val_acc: 0.8862
# Epoch 48/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0181 - acc: 0.9945 - val_loss: 0.8003 - val_acc: 0.8988
# Epoch 49/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0092 - acc: 0.9980 - val_loss: 0.9971 - val_acc: 0.8825
# Epoch 50/50
# 2000/2000 [==============================] - 3s 2ms/step - loss: 0.0189 - acc: 0.9960 - val_loss: 0.8586 - val_acc: 0.8875
