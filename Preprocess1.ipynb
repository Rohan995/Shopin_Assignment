# %%
import numpy as np
import cv2
import urllib
% matplotlib inline
from matplotlib import pyplot as plt

# %%
urllib.urlretrieve('https://assets.myntassets.com/h_640,q_90,w_480/v1/assets/images/2354027/2018/1/16/11516097831111-MsTaken-Women-Navy-Blue-Striped-Top-4731516097830960-1.jpg','practice.jpg')
# Out:
# ('practice.jpg', <httplib.HTTPMessage instance at 0x7f40092c9680>)

# %%
oimg = urllib.urlopen('https://assets.myntassets.com/h_640,q_90,w_480/v1/assets/images/2354027/2018/1/16/11516097831111-MsTaken-Women-Navy-Blue-Striped-Top-4731516097830960-1.jpg')

# %%
arr = np.asarray(bytearray(oimg.read()), dtype=np.uint8)
onimg = cv2.imdecode(arr, -1) # 'Load it as it is'

# %%
plt.imshow(onimg)

# %%
img = cv2.imread('practice.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.show()

# %%
height, width , channel = img.shape

# %%
print height
print width
# Out:
# 640
# 480

# %%
res_img =  cv2.resize(img,(224,224))

# %%
height1, width1, channel1 = res_img.shape

# %%
print height1
print width1
# Out:
# 224
# 224

# %%
plt.imshow(res_img)
plt.show()

# %%
crop_img = img[115:579, 60:420]

# %%
plt.imshow(crop_img)
plt.show()

# %%
cv2.imwrite('cropped.jpg',crop_img)
# Out:
# True
