# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import urllib2
import os as os
os.chdir('/home/himanshu')
from skimage import io

# %%
## Downloading the image from given URL

import urllib
urllib.urlretrieve('https://assets.myntassets.com/h_640,q_90,w_480/v1/assets/images/2354027/2018/1/16/11516097831111-MsTaken-Women-Navy-Blue-Striped-Top-4731516097830960-1.jpg', './test2.jpg')

# %%
## Reading image from URL
url = 'https://assets.myntassets.com/h_640,q_90,w_480/v1/assets/images/2354027/2018/1/16/11516097831111-MsTaken-Women-Navy-Blue-Striped-Top-4731516097830960-1.jpg'
img = io.imread(url)
plt.imshow(img)
plt.show()

# %%
## Height, width, channel of the image
h, w, c = img.shape
print img.shape
# Out:
# (640, 480, 3)

# %%
## Resizing
from skimage.transform import resize 

img_r = resize(img,(224,224))
plt.imshow(img_r)
# Out:
# /home/himanshu/anaconda/lib/python2.7/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
## cropping the image
crop = img[115:579,60:420,:]
plt.imshow(crop)

# %%
## saving the image
io.imsave('crop_sk.jpg', crop)
